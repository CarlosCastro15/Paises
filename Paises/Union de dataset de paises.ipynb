# %%
import pandas as pd
import numpy as np

# %%
excel_paises = pd.read_excel(r"C:\Users\07cas\OneDrive\Documentos\GitHub\Paises\Paises\Country.xlsx")

# %%
excel_paises
# Out:
#     Country Code           ShortName           TableName  \
# 0            AFG         Afghanistan         Afghanistan
# 1            ALB             Albania             Albania
# 2            DZA             Algeria             Algeria
# 3            ASM      American Samoa      American Samoa
# 4            ADO             Andorra             Andorra
# ..           ...                 ...                 ...
# 242          WBG  West Bank and Gaza  West Bank and Gaza
# 243          WLD               World               World
# 244          YEM               Yemen         Yemen, Rep.
# 245          ZMB              Zambia              Zambia
# 246          ZWE            Zimbabwe            Zimbabwe
#
#                                     LongName Alpha2Code        CurrencyUnit  \
# 0               Islamic State of Afghanistan         AF      Afghan afghani
# 1                        Republic of Albania         AL        Albanian lek
# ...

# %%
excel_paises2 = pd.read_excel(r"C:\Users\07cas\OneDrive\Documentos\GitHub\Paises\Paises\unemployment analysis.xlsx")

# %%
excel_paises2
# Out:
#                     Country Name Country Code   1991   1992   1993   1994  \
# 0    Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                    Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2     Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                         Angola          AGO   4.21   4.21   4.23   4.16
# 4                        Albania          ALB  10.31  30.01  25.26  20.84
# ..                           ...          ...    ...    ...    ...    ...
# 230                        Samoa          WSM   2.10   2.38   2.63   3.04
# 231                  Yemen, Rep.          YEM   8.32   8.31   8.35   8.34
# 232                 South Africa          ZAF  29.95  29.98  29.92  29.89
# 233                       Zambia          ZMB  18.90  19.37  19.70  18.43
# 234                     Zimbabwe          ZWE   4.94   4.99   4.97   4.96
#
#       1995   1996   1997   1998  ...   2012   2013   2014   2015   2016  \
# ...

# %%
#[ : , : ] a la derecha opera con and or entre otros y a la derecha puede agarrar cualquier columna
dftemp = excel_paises2.loc[ : , ["Country Name","Country Code",1991] ]

# %%
dftemp["Year"] = 1991

# %%
dftemp.columns = ['Country Name', 'Country Code', 'Value', 'Year']

# %%
dftemp.loc[ : , ['Country Name', 'Country Code', 'Year', 'Value'] ]
# Out:
#                     Country Name Country Code  Year  Value
# 0    Africa Eastern and Southern          AFE  1991   7.80
# 1                    Afghanistan          AFG  1991  10.65
# 2     Africa Western and Central          AFW  1991   4.42
# 3                         Angola          AGO  1991   4.21
# 4                        Albania          ALB  1991  10.31
# ..                           ...          ...   ...    ...
# 230                        Samoa          WSM  1991   2.10
# 231                  Yemen, Rep.          YEM  1991   8.32
# 232                 South Africa          ZAF  1991  29.95
# 233                       Zambia          ZMB  1991  18.90
# 234                     Zimbabwe          ZWE  1991   4.94
#
# [235 rows x 4 columns]

# %%
dftemp
# Out:
#                     Country Name Country Code  Value  Year
# 0    Africa Eastern and Southern          AFE   7.80  1991
# 1                    Afghanistan          AFG  10.65  1991
# 2     Africa Western and Central          AFW   4.42  1991
# 3                         Angola          AGO   4.21  1991
# 4                        Albania          ALB  10.31  1991
# ..                           ...          ...    ...   ...
# 230                        Samoa          WSM   2.10  1991
# 231                  Yemen, Rep.          YEM   8.32  1991
# 232                 South Africa          ZAF  29.95  1991
# 233                       Zambia          ZMB  18.90  1991
# 234                     Zimbabwe          ZWE   4.94  1991
#
# [235 rows x 4 columns]

# %%
dfnew = pd.DataFrame()
for y in excel_paises2.columns[ 2: ]:
    dftemp = excel_paises2.loc[ : , ["Country Name","Country Code",y] ]
    dftemp["Year"] = y
    dftemp.columns = ['Country Name', 'Country Code', 'Value', 'Year']
    dftemp.loc[ : , ['Country Name', 'Country Code', 'Year', 'Value'] ]

    dfnew = pd.concat([dfnew,dftemp])

# %%
dfnew
# Out:
#                     Country Name Country Code  Value  Year
# 0    Africa Eastern and Southern          AFE   7.80  1991
# 1                    Afghanistan          AFG  10.65  1991
# 2     Africa Western and Central          AFW   4.42  1991
# 3                         Angola          AGO   4.21  1991
# 4                        Albania          ALB  10.31  1991
# ..                           ...          ...    ...   ...
# 230                        Samoa          WSM   9.84  2021
# 231                  Yemen, Rep.          YEM  13.57  2021
# 232                 South Africa          ZAF  33.56  2021
# 233                       Zambia          ZMB  13.03  2021
# 234                     Zimbabwe          ZWE   5.17  2021
#
# [7285 rows x 4 columns]

# %%
excel_paises2.columns
# Out:
# Index(['Country Name', 'Country Code',           1991,           1992,
#                  1993,           1994,           1995,           1996,
#                  1997,           1998,           1999,           2000,
#                  2001,           2002,           2003,           2004,
#                  2005,           2006,           2007,           2008,
#                  2009,           2010,           2011,           2012,
#                  2013,           2014,           2015,           2016,
#                  2017,           2018,           2019,           2020,
#                  2021],
#       dtype='object')

# %%
merged=dfnew.merge(excel_paises, on=['Country Code'], suffixes=('_left','_right'))

# %%
merged
# Out:
#      Country Name Country Code  Value  Year    ShortName    TableName  \
# 0     Afghanistan          AFG  10.65  1991  Afghanistan  Afghanistan
# 1     Afghanistan          AFG  10.82  1992  Afghanistan  Afghanistan
# 2     Afghanistan          AFG  10.72  1993  Afghanistan  Afghanistan
# 3     Afghanistan          AFG  10.73  1994  Afghanistan  Afghanistan
# 4     Afghanistan          AFG  11.18  1995  Afghanistan  Afghanistan
# ...           ...          ...    ...   ...          ...          ...
# 6629     Zimbabwe          ZWE   4.78  2017     Zimbabwe     Zimbabwe
# 6630     Zimbabwe          ZWE   4.80  2018     Zimbabwe     Zimbabwe
# 6631     Zimbabwe          ZWE   4.83  2019     Zimbabwe     Zimbabwe
# 6632     Zimbabwe          ZWE   5.35  2020     Zimbabwe     Zimbabwe
# 6633     Zimbabwe          ZWE   5.17  2021     Zimbabwe     Zimbabwe
#
#                           LongName Alpha2Code    CurrencyUnit  \
# 0     Islamic State of Afghanistan         AF  Afghan afghani
# ...

# %%
dfmerged = merged.loc[ : , ["Country Name","Country Code","CurrencyUnit","Region"] ]

# %%
dfmerged
# Out:
#      Country Name Country Code    CurrencyUnit              Region
# 0     Afghanistan          AFG  Afghan afghani          South Asia
# 1     Afghanistan          AFG  Afghan afghani          South Asia
# 2     Afghanistan          AFG  Afghan afghani          South Asia
# 3     Afghanistan          AFG  Afghan afghani          South Asia
# 4     Afghanistan          AFG  Afghan afghani          South Asia
# ...           ...          ...             ...                 ...
# 6629     Zimbabwe          ZWE     U.S. dollar  Sub-Saharan Africa
# 6630     Zimbabwe          ZWE     U.S. dollar  Sub-Saharan Africa
# 6631     Zimbabwe          ZWE     U.S. dollar  Sub-Saharan Africa
# 6632     Zimbabwe          ZWE     U.S. dollar  Sub-Saharan Africa
# 6633     Zimbabwe          ZWE     U.S. dollar  Sub-Saharan Africa
#
# [6634 rows x 4 columns]
